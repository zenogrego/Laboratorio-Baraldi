# %% [markdown]
# # LABORATORIO 04/05/22

# %% [markdown]
# $ \textbf{obiettivo giornata:} $ verificare attraverso l'uso dello SPA-LEED che quello che effettivamente viene depositato sulla superficie sia grafene. Vogliamo quindi fare misure su questo sistema con il LEED tradizionale e avere delle energie di riferimento e, una volta fatto ciò, vogliamo distruggere il sistema con il grafene e riavere quindi la superficie pulita per fare nuove misure successivamente. $ \\ $
#
# $\underline{Osservazione:} $ lo SPA-LEED ha una transfer width di 1 ordine di grandezza maggiore del LEED. Riesco quindi a vedere meglio i domini. $ \\ $
#
# Vogliamo quindi poter fare misure in condizioni uguali per quanto riguarda le coordinate LEED e per quanto riguarda le energie in gioco. $ \\ $
#
# $\underline{Nota:} $ se nell'immagine ad alta energia vedo la (1x2), mi aspetto che sia la superficie ricostruita.

# %% [markdown]
# # Esercizio
#
# ![IMG_3984.jpg](attachment:f0bf4de5-6676-426f-8db9-5e32f761f068.jpg)
#
# Può essere utile l'articolo sul pattern di Moire (Zeller 2017).  $ \\ $
#
# Ci interess capire come è orientato il grafene rispetto l'Ir(311). Se scegliamo un punto come sistema di riferimento con il centro del mio esagono, è meglio. I due vettori dell' Ir sono allineati con i due vettori del graphene.
#
# $ \textbf{Domanda:} $ allora, dopo quante celle reticolari dell'esagono avrà, l'esagono esattamente al centro?
#
# $ \textbf{Risposta:} $ $ \quad $ $2.46 m = 2.71 (m-1) $ $ \\ $
#
# $ \textbf{Domanda:} $ esiste per questo raggio un multiplo dei due vettori che non si discosta molto da questo raggio?

# %% [markdown]
# ### Presa immagini LEED
#
# (17:00 ) Prima batteria immagini: Energie comprese tra $ 66 $ eV e $ 126 $ eV a $ 200 $ frames a passi di $ 2 $ eV
#
#   E [ev] |   frames  |  image|
# ----|------|----|
# 66  | 200| 4_5_22_000 |
# 68  | 200| 4_5_22_001 |
# 70 | 200| 4_5_22_002|
# 72| 200| 4_5_22_003 |
# 74| 200| 4_5_22_004 |
# 76 |200| 4_5_22_005 |
# 78| 200| 4_5_22_006 |
# 80| 200| 4_5_22_007 |
# 82| 200| 4_5_22_008 |
# 84| 200| 4_5_22_009 |
# 86| 200| 4_5_22_010 |
# 88| 200| 4_5_22_011 |
# 90| 200| 4_5_22_012 |
# 92| 200| 4_5_22_013 |
# 94| 200| 4_5_22_014 |

# %% [markdown]
# (17:24) pausa di $ 15 $ minuti per lasciar riposare il filamento

# %% [markdown]
# (17:45) Seconda batteria immagini:

# %% [markdown]
# ### Presa immagini LEED
#
#   E [ev] |   frames  |  image|
# ----|------|----|
# 96  | 200| 4_5_22_015 |
# 98  | 200| 4_5_22_016 |
# 100 | 200| 4_5_22_017|
# 102| 200| 4_5_22_018 |
# 104| 200| 4_5_22_019 |
# 106 |200| 4_5_22_020 |
# 108| 200| 4_5_22_021 |
# 110| 200| 4_5_22_022 |
# 112| 200| 4_5_22_023 |
# 114| 200| 4_5_22_024 |
# 116| 200| 4_5_22_025 |
# 118| 200| 4_5_22_026 |
# 120| 200| 4_5_22_027 |
# 122| 200| 4_5_22_028 |
# 124| 200| 4_5_22_029 |
# 126| 200| 4_5_22_030 |

# %% [markdown]
# Calcolo rapporto vettori di reticolo reciproco Ir(311) e vettori di reticolo reciproco graphene:

# %% [markdown]
# ### Reticolo diretto
#
# i vettori primitivi di reticolo diretto sono:
#
# $ a_1 = \Big(2.7082 \quad ; \quad 0\Big) $ $ \\ $
# $ a_2 = \Big(1.35 \quad ; \quad 4.49\Big) $
#
# modulo dei due vettori di reticolo diretto:
#
# $\vert a_1 \vert = 2.7082$ angstrom $ \\ $
# $\vert a_2 \vert = 4.6885$ angstrom $ \\ $
#
# angolo tra $ a_1 $ e $ a_2 $: $\quad$  73.26 deg

# %% [markdown]
# ### Reticolo reciproco
#
# i vettori primitivi di reticolo reciproco sono:
#
# $ b_1 = \Big(2.32 \quad ; \quad -0.6976\Big) $ $ \\ $
# $ b_2 = \Big(0 \quad ; \quad 1.3993\Big) $
#
# modulo dei due vettori di reticolo reciproco:
#
# $\vert b_1 \vert = 2.42265$ angstrom $ \\ $
# $\vert b_2 \vert = 1.39937$ angstrom $ \\ $
#
# angolo tra $ b_1 $ e $ b_2 $: $\quad$  106.73 deg

# %% [markdown]
# rapporto tra moduli di $ b_1 $ e $ b_2 $ con i vettori di reticolo reciproco del graphene $ G $:
#
# $\vert G \vert = 2.9444$ angstrom $ \\ $
#
# $ \dfrac{\vert b_1 \vert}{\vert G \vert} = \dfrac{2.4226}{2.9444} = \boxed{0.8227} $ $ \\ $
#
# $ \dfrac{\vert b_2 \vert}{\vert G \vert} = \dfrac{1.3994}{2.9444} = \boxed{0.4752} $ $ \\ $

# %% [markdown]
# Alla fine non abbiamo avuto il tempo di vedere le immagini con lo SPA-LEED e nemmeno il tempo di distruggere il graphene.
